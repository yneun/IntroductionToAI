# %%
#Exercise 1

#data handling

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_excel('data_set_train.xlsx')

# %%
df
# Out:
#       aptnm(아파트 이름) yyyyqrt(거래년도 분기별)  price(가격)  con_year(건축년도) dong(동)  \
# 0          강남역우정에쉐르            2006Q1       9000            2004     역삼동
# 1          강남역우정에쉐르            2006Q1       9000            2004     역삼동
# 2           개포주공1단지            2006Q1      73000            1982     개포동
# 3           개포주공1단지            2006Q1      70000            1982     개포동
# 4           개포주공1단지            2006Q1      40000            1982     개포동
# ...             ...               ...        ...             ...     ...
# 17395         현대빌라트            2017Q3     179000            1998     청담동
# 17396        현대이스트빌            2017Q3     122500            1999     역삼동
# 17397         현대하이츠            2017Q3      64000            2004     역삼동
# 17398          현대한강            2017Q3     170000            1992     청담동
# 17399          현대한강            2017Q3     170000            1992     청담동
#
#        area(면적)  floor(층수)  Latitude(위도)  Longtitude(경도)     gdp  ...  \
# 0         17.23          7     37.494204      127.043545  225613  ...
# 1         17.23          7     37.494204      127.043545  225613  ...
# 2         50.38          3     37.478407      127.061375  225613  ...
# 3         50.64          5     37.484609      127.067275  225613  ...
# 4         35.44          4     37.482445      127.051278  225613  ...
# ...         ...        ...           ...             ...     ...  ...
# 17395    169.63          8     37.526956      127.053126  446835  ...
# 17396    244.14          4     37.496260      127.046404  446835  ...
# 17397     96.21          1     37.491379      127.034880  446835  ...
# 17398    136.26          8     37.524675      127.056226  446835  ...
# 17399    136.26          8     37.524675      127.056226  446835  ...
#
#        dis_subway(지하철역과의 거리)  brand_r(유명 아파트 브랜드순)  n_home(세대수)  n_dong(동수)  \
# 0                 849.353653                     0           52           1
# 1                 849.353653                     0           52           1
# 2                1486.178329                     0         5040         124
# 3                1160.598717                     0         5040         124
# 4                 650.325555                     0         5040         124
# ...                      ...                   ...          ...         ...
# 17395             874.719438                     0           14           1
# 17396             944.717800                     0           12           1
# 17397             812.764336                     0           12           1
# 17398             717.729425                     0           18           1
# 17399             717.729425                     0           18           1
#
#        parking_per(세대별 주차장수)  Heater(난방 시스템)  Yongpae(용적률)  Gunpae(건폐율)  \
# 0                       0.75            개별난방         536.0         58.0
# 1                       0.75            개별난방         536.0         58.0
# 2                       0.49            개별난방          72.0         15.0
# 3                       0.49            개별난방          72.0         15.0
# 4                       0.49            개별난방          72.0         15.0
# ...                      ...             ...           ...          ...
# 17395                   1.85            개별난방         221.0         37.0
# 17396                   2.16            개별난방         239.0         46.0
# 17397                   1.25            개별난방         287.0         58.0
# 17398                      -            개별난방         290.0          NaN
# 17399                      -            개별난방         290.0          NaN
#
#        Highest(최고층)  Lowest(최저층)
# 0                13           12
# 1                13           12
# 2                 5            5
# 3                 5            5
# 4                 5            5
# ...             ...          ...
# 17395             7            7
# 17396             6            6
# 17397             7            6
# 17398            10           10
# 17399            10           10
#
# [17400 rows x 29 columns]

# %%
df.shape
# Out:
# (17400, 29)

# %%
df.columns
# Out:
# Index(['aptnm(아파트 이름)', 'yyyyqrt(거래년도 분기별)', 'price(가격)', 'con_year(건축년도)',
#        'dong(동)', 'area(면적)', 'floor(층수)', 'Latitude(위도)', 'Longtitude(경도)',
#        'gdp', 'e_grwth(경제성장률)', 'Seoul_l.rate(지가상승률)', 'house_rate(담보대출금리)',
#        'dis_park(국립 공원과의 거리)', 'dis_highschool(고등학교와의 거리)',
#        'dis_reconst(재개발 지역과의 거리)', 'dis_univ(대학과의 거리)',
#        'dis_hospital(종합 병원과의 거리)', 'dis_museum(국립 박물관과의 거리)',
#        'dis_subway(지하철역과의 거리)', 'brand_r(유명 아파트 브랜드순)', 'n_home(세대수)',
#        'n_dong(동수)', 'parking_per(세대별 주차장수)', 'Heater(난방 시스템)', 'Yongpae(용적률)',
#        'Gunpae(건폐율)', 'Highest(최고층)', 'Lowest(최저층)'],
#       dtype='object')

# %%
df.describe()
# Out:
#            price(가격)  con_year(건축년도)      area(면적)     floor(층수)  \
# count   17400.000000    17400.000000  17400.000000  17400.000000
# mean    80334.523736     1992.928563     71.217003      7.451322
# std     45557.247993       10.250319     34.905756      5.627460
# min      1000.000000     1978.000000     16.780000     -1.000000
# 25%     53500.000000     1982.000000     42.550000      3.000000
# 50%     74500.000000     1993.000000     59.950000      5.000000
# 75%     96000.000000     2004.000000     84.910000     11.000000
# max    570000.000000     2014.000000    273.830000     45.000000
#
#        Latitude(위도)  Longtitude(경도)            gdp  e_grwth(경제성장률)  \
# count  17400.000000    17400.000000   17400.000000    17400.000000
# mean      37.494002      127.060032  330970.131494        3.659925
# std        0.012002        0.017059   62803.867282        1.806509
# min       37.460256      127.018178  225613.000000       -1.900000
# 25%       37.484704      127.048360  277832.000000        2.700000
# 50%       37.493391      127.058356  335960.000000        3.500000
# 75%       37.499314      127.071381  385702.000000        4.900000
# max       37.533197      127.103555  446835.000000        7.400000
#
#        Seoul_l.rate(지가상승률)  house_rate(담보대출금리)  ...  dis_hospital(종합 병원과의 거리)  \
# count         17400.000000        17400.000000  ...              17400.000000
# mean              0.064492            6.054785  ...               1063.010719
# std               0.322120            0.607412  ...                523.568572
# min              -2.642750            5.263300  ...                 41.632692
# 25%               0.001632            5.499746  ...                635.176776
# 50%               0.016252            5.883320  ...                975.124492
# 75%               0.099044            6.576878  ...               1459.461217
# max               0.624673            7.415442  ...               3470.829811
#
#        dis_museum(국립 박물관과의 거리)  dis_subway(지하철역과의 거리)  brand_r(유명 아파트 브랜드순)  \
# count             17400.000000           17400.000000          17400.000000
# mean                985.858326             677.704437              1.147816
# std                 374.407888             394.313279              3.256703
# min                  87.490136              47.486971              0.000000
# 25%                 693.430670             318.596967              0.000000
# 50%                1032.477721             579.455311              0.000000
# 75%                1220.076628             899.616370              0.000000
# max                3323.864542            2559.068365             15.000000
#
#         n_home(세대수)    n_dong(동수)  Yongpae(용적률)   Gunpae(건폐율)  Highest(최고층)  \
# count  17400.000000  17400.000000  16137.000000  15771.000000  17400.000000
# mean    1724.199713     30.414713    251.880771     24.703887     13.693218
# std     1852.886244     42.795932    209.698580     15.030962      7.558171
# min        9.000000      1.000000     72.000000     12.000000      4.000000
# 25%      206.000000      2.000000     80.000000     16.000000      5.000000
# 50%      900.000000      8.000000    223.000000     19.000000     14.000000
# 75%     2840.000000     34.000000    285.000000     26.000000     21.000000
# max     5040.000000    124.000000   2435.000000    204.000000     46.000000
#
#         Lowest(최저층)
# count  17400.000000
# mean      11.013908
# std        5.629246
# min        3.000000
# 25%        5.000000
# 50%       12.000000
# 75%       15.000000
# max       26.000000
#
# [8 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17400 entries, 0 to 17399
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   aptnm(아파트 이름)              17400 non-null  object
#  1   yyyyqrt(거래년도 분기별)          17400 non-null  object
#  2   price(가격)                  17400 non-null  int64
#  3   con_year(건축년도)             17400 non-null  int64
#  4   dong(동)                    17400 non-null  object
#  5   area(면적)                   17400 non-null  float64
#  6   floor(층수)                  17400 non-null  int64
#  7   Latitude(위도)               17400 non-null  float64
#  8   Longtitude(경도)             17400 non-null  float64
#  9   gdp                        17400 non-null  int64
#  10  e_grwth(경제성장률)             17400 non-null  float64
#  11  Seoul_l.rate(지가상승률)        17400 non-null  float64
#  12  house_rate(담보대출금리)         17400 non-null  float64
#  13  dis_park(국립 공원과의 거리)       17400 non-null  float64
#  14  dis_highschool(고등학교와의 거리)  17400 non-null  float64
#  15  dis_reconst(재개발 지역과의 거리)   17400 non-null  float64
#  16  dis_univ(대학과의 거리)          17400 non-null  float64
#  17  dis_hospital(종합 병원과의 거리)   17400 non-null  float64
#  18  dis_museum(국립 박물관과의 거리)    17400 non-null  float64
#  19  dis_subway(지하철역과의 거리)      17400 non-null  float64
#  20  brand_r(유명 아파트 브랜드순)       17400 non-null  int64
#  21  n_home(세대수)                17400 non-null  int64
#  22  n_dong(동수)                 17400 non-null  int64
#  23  parking_per(세대별 주차장수)      17400 non-null  object
#  24  Heater(난방 시스템)             17400 non-null  object
#  25  Yongpae(용적률)               16137 non-null  float64
#  26  Gunpae(건폐율)                15771 non-null  float64
#  27  Highest(최고층)               17400 non-null  int64
#  28  Lowest(최저층)                17400 non-null  int64
# dtypes: float64(15), int64(9), object(5)
# memory usage: 3.8+ MB

# %%
df['yyyyqrt(거래년도 분기별)'].unique()
# Out:
# array(['2006Q1', '2006Q2', '2006Q3', '2006Q4', '2007Q1', '2007Q2',
#        '2007Q3', '2007Q4', '2008Q1', '2008Q2', '2008Q3', '2008Q4',
#        '2009Q1', '2009Q2', '2009Q3', '2009Q4', '2010Q1', '2010Q2',
#        '2010Q3', '2010Q4', '2011Q1', '2011Q2', '2011Q3', '2011Q4',
#        '2012Q1', '2012Q2', '2012Q3', '2012Q4', '2013Q1', '2013Q2',
#        '2013Q3', '2013Q4', '2014Q1', '2014Q2', '2014Q3', '2014Q4',
#        '2015Q1', '2015Q2', '2015Q3', '2015Q4', '2016Q1', '2016Q2',
#        '2016Q3', '2016Q4', '2017Q1', '2017Q2', '2017Q3'], dtype=object)

# %%
#Check the missing cells
df[df['Yongpae(용적률)'].isnull()].head()
# Out:
#     aptnm(아파트 이름) yyyyqrt(거래년도 분기별)  price(가격)  con_year(건축년도) dong(동)  \
# 399       개포주공6단지            2006Q1      77100            1983     개포동
# 400       개포주공6단지            2006Q1      60600            1983     개포동
# 401       개포주공6단지            2006Q1      49000            1983     개포동
# 402       개포주공6단지            2006Q1      59400            1983     개포동
# 403       개포주공6단지            2006Q1      59500            1983     개포동
#
#      area(면적)  floor(층수)  Latitude(위도)  Longtitude(경도)     gdp  ...  \
# 399     73.02         10     37.478407      127.061375  225613  ...
# 400     60.13         14     37.494581      127.075275  225613  ...
# 401     53.06         13     37.484335      127.071381  225613  ...
# 402     60.13          2     37.484609      127.067275  225613  ...
# 403     60.13         14     37.478407      127.061375  225613  ...
#
#      dis_subway(지하철역과의 거리)  brand_r(유명 아파트 브랜드순)  n_home(세대수)  n_dong(동수)  \
# 399            1486.178329                     0         1060           9
# 400             316.902800                     0         1060           9
# 401            1155.513971                     0         1060           9
# 402            1160.598717                     0         1060           9
# 403            1486.178329                     0         1060           9
#
#      parking_per(세대별 주차장수)  Heater(난방 시스템)  Yongpae(용적률)  Gunpae(건폐율)  \
# 399                   0.28            중앙난방           NaN          NaN
# 400                   0.28            중앙난방           NaN          NaN
# 401                   0.28            중앙난방           NaN          NaN
# 402                   0.28            중앙난방           NaN          NaN
# 403                   0.28            중앙난방           NaN          NaN
#
#      Highest(최고층)  Lowest(최저층)
# 399            15           13
# 400            15           13
# 401            15           13
# 402            15           13
# 403            15           13
#
# [5 rows x 29 columns]

# %%
df['Yongpae(용적률)']=df['Yongpae(용적률)'].replace(np.nan,df['Yongpae(용적률)'].mean())
df['Gunpae(건폐율)']=df['Gunpae(건폐율)'].replace(np.nan,df['Gunpae(건폐율)'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17400 entries, 0 to 17399
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   aptnm(아파트 이름)              17400 non-null  object
#  1   yyyyqrt(거래년도 분기별)          17400 non-null  object
#  2   price(가격)                  17400 non-null  int64
#  3   con_year(건축년도)             17400 non-null  int64
#  4   dong(동)                    17400 non-null  object
#  5   area(면적)                   17400 non-null  float64
#  6   floor(층수)                  17400 non-null  int64
#  7   Latitude(위도)               17400 non-null  float64
#  8   Longtitude(경도)             17400 non-null  float64
#  9   gdp                        17400 non-null  int64
#  10  e_grwth(경제성장률)             17400 non-null  float64
#  11  Seoul_l.rate(지가상승률)        17400 non-null  float64
#  12  house_rate(담보대출금리)         17400 non-null  float64
#  13  dis_park(국립 공원과의 거리)       17400 non-null  float64
#  14  dis_highschool(고등학교와의 거리)  17400 non-null  float64
#  15  dis_reconst(재개발 지역과의 거리)   17400 non-null  float64
#  16  dis_univ(대학과의 거리)          17400 non-null  float64
#  17  dis_hospital(종합 병원과의 거리)   17400 non-null  float64
#  18  dis_museum(국립 박물관과의 거리)    17400 non-null  float64
#  19  dis_subway(지하철역과의 거리)      17400 non-null  float64
#  20  brand_r(유명 아파트 브랜드순)       17400 non-null  int64
#  21  n_home(세대수)                17400 non-null  int64
#  22  n_dong(동수)                 17400 non-null  int64
#  23  parking_per(세대별 주차장수)      17400 non-null  object
#  24  Heater(난방 시스템)             17400 non-null  object
#  25  Yongpae(용적률)               17400 non-null  float64
#  26  Gunpae(건폐율)                17400 non-null  float64
#  27  Highest(최고층)               17400 non-null  int64
#  28  Lowest(최저층)                17400 non-null  int64
# dtypes: float64(15), int64(9), object(5)
# memory usage: 3.8+ MB

# %%
df['dong(동)'].value_counts()
# Out:
# 개포동     5866
# 역삼동     3729
# 대치동     2411
# 수서동     1937
# 도곡동     1032
# 청담동      868
# 논현동      636
# 삼성동      569
# 일원동      333
# 세곡동       17
# 압구정동       2
# Name: dong(동), dtype: int64

# %%
df['yyyyqrt(거래년도 분기별)'].value_counts()
# Out:
# 2017Q1    780
# 2006Q1    703
# 2006Q3    682
# 2006Q4    670
# 2006Q2    562
# 2017Q2    537
# 2016Q3    419
# 2012Q4    416
# 2008Q2    416
# 2015Q2    405
# 2011Q3    397
# 2016Q1    389
# 2007Q4    386
# 2008Q1    385
# 2015Q3    373
# 2015Q1    370
# 2016Q2    369
# 2011Q4    367
# 2011Q1    357
# 2011Q2    353
# 2010Q1    353
# 2017Q3    352
# 2007Q2    349
# 2015Q4    348
# 2013Q3    343
# 2014Q4    336
# 2013Q2    334
# 2009Q1    325
# 2013Q1    325
# 2013Q4    323
# 2014Q1    317
# 2007Q3    315
# 2010Q4    313
# 2010Q3    310
# 2016Q4    306
# 2014Q3    304
# 2009Q2    303
# 2014Q2    298
# 2009Q3    295
# 2009Q4    280
# 2012Q2    277
# 2007Q1    270
# 2010Q2    241
# 2012Q1    238
# 2008Q3    219
# 2012Q3    204
# 2008Q4    186
# Name: yyyyqrt(거래년도 분기별), dtype: int64

# %%
data1=df.loc[:,'yyyyqrt(거래년도 분기별)':'Longtitude(경도)']
data1.head()
# Out:
#   yyyyqrt(거래년도 분기별)  price(가격)  con_year(건축년도) dong(동)  area(면적)  floor(층수)  \
# 0            2006Q1       9000            2004     역삼동     17.23          7
# 1            2006Q1       9000            2004     역삼동     17.23          7
# 2            2006Q1      73000            1982     개포동     50.38          3
# 3            2006Q1      70000            1982     개포동     50.64          5
# 4            2006Q1      40000            1982     개포동     35.44          4
#
#    Latitude(위도)  Longtitude(경도)
# 0     37.494204      127.043545
# 1     37.494204      127.043545
# 2     37.478407      127.061375
# 3     37.484609      127.067275
# 4     37.482445      127.051278

# %%
data1=df[['yyyyqrt(거래년도 분기별)','price(가격)','dong(동)','Latitude(위도)','Longtitude(경도)','Seoul_l.rate(지가상승률)','dis_subway(지하철역과의 거리)']]
data1.head()
# Out:
#   yyyyqrt(거래년도 분기별)  price(가격) dong(동)  Latitude(위도)  Longtitude(경도)  \
# 0            2006Q1       9000     역삼동     37.494204      127.043545
# 1            2006Q1       9000     역삼동     37.494204      127.043545
# 2            2006Q1      73000     개포동     37.478407      127.061375
# 3            2006Q1      70000     개포동     37.484609      127.067275
# 4            2006Q1      40000     개포동     37.482445      127.051278
#
#    Seoul_l.rate(지가상승률)  dis_subway(지하철역과의 거리)
# 0             0.152881             849.353653
# 1             0.152881             849.353653
# 2             0.152881            1486.178329
# 3             0.152881            1160.598717
# 4             0.152881             650.325555

# %%
data1.tail()
# Out:
#       yyyyqrt(거래년도 분기별)  price(가격) dong(동)  Latitude(위도)  Longtitude(경도)  \
# 17395            2017Q3     179000     청담동     37.526956      127.053126
# 17396            2017Q3     122500     역삼동     37.496260      127.046404
# 17397            2017Q3      64000     역삼동     37.491379      127.034880
# 17398            2017Q3     170000     청담동     37.524675      127.056226
# 17399            2017Q3     170000     청담동     37.524675      127.056226
#
#        Seoul_l.rate(지가상승률)  dis_subway(지하철역과의 거리)
# 17395             0.069818             874.719438
# 17396             0.069818             944.717800
# 17397             0.069818             812.764336
# 17398             0.069818             717.729425
# 17399             0.069818             717.729425

# %%
#Exercise 2
dong = ['Chungdam', 'Apgujeong', 'Dogok', 'Samsung','Daechi','Gaepo','Yeocksam', 'Suseo']
lon=[127.0487,127.0303,127.0438,127.0565,127.0611,127.0609,127.0374,127.1052]
lat=[37.5232,37.5317,37.4898,37.5140,37.4995,37.4790,37.4999,37.4890]
data = {'Dong':dong,'Lat':lat,'Lng' : lon}
dong_data=pd.DataFrame(data=data)
dong_data
# Out:
#         Dong      Lat       Lng
# 0   Chungdam  37.5232  127.0487
# 1  Apgujeong  37.5317  127.0303
# 2      Dogok  37.4898  127.0438
# 3    Samsung  37.5140  127.0565
# 4     Daechi  37.4995  127.0611
# 5      Gaepo  37.4790  127.0609
# 6   Yeocksam  37.4999  127.0374
# 7      Suseo  37.4890  127.1052

# %%
# Location plot (Spatial information)
plt.figure(figsize=(8, 5))
plt.scatter(data1['Longtitude(경도)'],data1['Latitude(위도)'],alpha=0.1)

for i in range(8): # Marking areas
    plt.text(dong_data['Lng'][i],dong_data['Lat'][i],dong_data['Dong'][i],fontsize=12)
plt.scatter(dong_data['Lng'],dong_data['Lat'],edgecolors="black",c="None",s=2500,alpha=0.3)  
plt.xlabel("Longitude")
plt.ylabel("Latitude")
# Out:
# Text(0, 0.5, 'Latitude')

# %%
#Changing the names of columns
data2=data1.copy()
data2.columns=['yearqrt', 'price', 'dong','Lat', 'Lng','rate','station_dist']
data2
# Out:
#       yearqrt   price dong        Lat         Lng      rate  station_dist
# 0      2006Q1    9000  역삼동  37.494204  127.043545  0.152881    849.353653
# 1      2006Q1    9000  역삼동  37.494204  127.043545  0.152881    849.353653
# 2      2006Q1   73000  개포동  37.478407  127.061375  0.152881   1486.178329
# 3      2006Q1   70000  개포동  37.484609  127.067275  0.152881   1160.598717
# 4      2006Q1   40000  개포동  37.482445  127.051278  0.152881    650.325555
# ...       ...     ...  ...        ...         ...       ...           ...
# 17395  2017Q3  179000  청담동  37.526956  127.053126  0.069818    874.719438
# 17396  2017Q3  122500  역삼동  37.496260  127.046404  0.069818    944.717800
# 17397  2017Q3   64000  역삼동  37.491379  127.034880  0.069818    812.764336
# 17398  2017Q3  170000  청담동  37.524675  127.056226  0.069818    717.729425
# 17399  2017Q3  170000  청담동  37.524675  127.056226  0.069818    717.729425
#
# [17400 rows x 7 columns]

# %%
#visualize price at 2006 and 2017
plt.figure(figsize=(25, 8))

tp=data2[data2['yearqrt'].str.contains("2006Q")]
plt.subplot(1,2,1) # price plot
plt.scatter(x=tp["Lng"], y=tp["Lat"], c=tp["price"],s=200, cmap=plt.cm.Reds)
plt.colorbar(label='color')

#Marking areas
for i in range(8):
    plt.text(dong_data['Lng'][i],dong_data['Lat'][i],dong_data['Dong'][i],fontsize=12)
    
plt.scatter(dong_data['Lng'],dong_data['Lat'],edgecolor="black",c="None",s=1500,alpha=0.3)  
plt.title("2006"); plt.xlabel("Longitude"); plt.ylabel("Latitude");


tp=data2[data2['yearqrt'].str.contains("2017Q")]
plt.subplot(1,2,2)  # price plot
plt.scatter(x=tp["Lng"], y=tp["Lat"], c=tp["price"], s=200,cmap=plt.cm.Reds)
plt.colorbar(label='color')
                              
#Marking areas                              
for i in range(8):
     plt.text(dong_data['Lng'][i],dong_data['Lat'][i],dong_data['Dong'][i],fontsize=12)
    
plt.scatter(dong_data['Lng'],dong_data['Lat'],edgecolor="black",c="None",s=1500,alpha=0.3)
plt.title("2017"); plt.xlabel("Longitude"); plt.ylabel("Latitude");

# %%
data_gaepo=data2[data2['dong']=='개포동']
data_gaepo.head()
# Out:
#   yearqrt  price dong        Lat         Lng      rate  station_dist
# 2  2006Q1  73000  개포동  37.478407  127.061375  0.152881   1486.178329
# 3  2006Q1  70000  개포동  37.484609  127.067275  0.152881   1160.598717
# 4  2006Q1  40000  개포동  37.482445  127.051278  0.152881    650.325555
# 5  2006Q1  56000  개포동  37.478407  127.061375  0.152881   1486.178329
# 6  2006Q1  40500  개포동  37.494581  127.075275  0.152881    316.902800

# %%
data_gaepo_time=data_gaepo.groupby('yearqrt').mean()  
data_gaepo_time.head()
# Out:
#                 price        Lat         Lng      rate  station_dist
# yearqrt
# 2006Q1   66954.968288  37.483163  127.063829  0.152881   1106.719865
# 2006Q2   69240.408163  37.484935  127.066870  0.430146   1009.206136
# 2006Q3   71064.128440  37.484071  127.063688  0.367231   1060.919660
# 2006Q4   86538.140704  37.484502  127.065871  0.624673   1033.040965
# 2007Q1   79064.285714  37.487090  127.068583  0.100708    846.666678

# %%
plt.figure(figsize=(20,8))
plt.title("Gaepo")
plt.plot(data_gaepo_time['price'])
plt.xticks(rotation=45)
plt.show()

# %%
#Exercise 3

#for printing korean words
import matplotlib.font_manager as fm

#print korean fonts that you have
#font_list = [font.name for font in fm.fontManager.ttflist]
#print(font_list)
plt.rcParams['font.family'] = 'Malgun Gothic'

import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
dong=df['dong(동)'].unique()
plt.figure(figsize=(50,100))
count=1
for i in dong:
    tmp=df[df['dong(동)']==i]
    tp=tmp.groupby('yyyyqrt(거래년도 분기별)').mean()
    plt.subplot(3,4,count)
    plt.plot(tp['price(가격)'],linewidth=3.0)
    plt.title(i,fontsize=80)
    plt.yticks(fontsize=50)
    count=count+1
plt.show()
# Out:
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50669 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54252 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 52397 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45812 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 52824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54788 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50517 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50669 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54252 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 52397 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 45812 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 52824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 45436 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54788 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50517 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#Exercise 4

dong_col=[]
for i in dong:
    tmp=df[df['dong(동)']==i]
    tp=tmp.groupby('yyyyqrt(거래년도 분기별)').mean()
    print(i, ' : ', len(tp), end=' ')
    dong_col.append(i)
    print('\n')
# Out:
# 역삼동  :  47
#
# 개포동  :  47
#
# 청담동  :  47
#
# 대치동  :  46
#
# 삼성동  :  47
#
# 논현동  :  38
#
# 도곡동  :  32
#
# 수서동  :  32
#
# 일원동  :  32
#
# 압구정동  :  1
#
# 세곡동  :  6

# %%
plt.figure(figsize=(50,100))
count=1; date=[];
nMA = 2 # number of Pre(or post) samples to average
for i in dong:
    tmp=df[df['dong(동)']==i]
    tp=tmp.groupby('yyyyqrt(거래년도 분기별)').mean().copy()
    ls=[]
    for j in range(nMA,len(tp)-nMA): # Averaging 5 samples
        ls.append(tp['price(가격)'].iloc[j-nMA:j+nMA].mean())
    
    d=pd.DataFrame({'Time':tp.index.values[nMA:len(tp)-nMA],'Mean_Price':ls})
    plt.subplot(6,2,count)
    plt.title(i,fontsize=80);plt.yticks(fontsize=50)
    plt.plot(d['Time'],d['Mean_Price'])
    count=count+1
# Out:
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50669 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54252 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 52397 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45812 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 52824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54788 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44257 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50517 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50669 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54252 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 52397 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 45812 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 52824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 45436 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54788 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44257 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50517 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
corr=df.corr()
corr.head(15)
# Out:
#                            price(가격)  con_year(건축년도)  area(면적)  floor(층수)  \
# price(가격)                   1.000000        0.085364  0.711187   0.094599
# con_year(건축년도)              0.085364        1.000000  0.439237   0.390900
# area(면적)                    0.711187        0.439237  1.000000   0.185766
# floor(층수)                   0.094599        0.390900  0.185766   1.000000
# Latitude(위도)                0.105059        0.528441  0.434611   0.162481
# Longtitude(경도)             -0.079797       -0.428207 -0.238154  -0.162969
# gdp                         0.289566        0.017524  0.112332  -0.005394
# e_grwth(경제성장률)             -0.132575        0.018824 -0.063985  -0.014200
# Seoul_l.rate(지가상승률)        -0.044081        0.003777 -0.049426  -0.032827
# house_rate(담보대출금리)         -0.016064        0.064364  0.073215   0.096666
# dis_park(국립 공원과의 거리)        0.124167       -0.249766 -0.066577  -0.062905
# dis_highschool(고등학교와의 거리)   0.008956        0.020907  0.034017  -0.051315
# dis_reconst(재개발 지역과의 거리)   -0.217519        0.288396  0.025094   0.086767
# dis_univ(대학과의 거리)          -0.025299       -0.607955 -0.331806  -0.233695
# dis_hospital(종합 병원과의 거리)   -0.027211       -0.567171 -0.351692  -0.334654
#
#                            Latitude(위도)  Longtitude(경도)       gdp  \
# price(가격)                      0.105059       -0.079797  0.289566
# con_year(건축년도)                 0.528441       -0.428207  0.017524
# area(면적)                       0.434611       -0.238154  0.112332
# floor(층수)                      0.162481       -0.162969 -0.005394
# Latitude(위도)                   1.000000       -0.439299  0.025258
# Longtitude(경도)                -0.439299        1.000000 -0.048094
# gdp                            0.025258       -0.048094  1.000000
# e_grwth(경제성장률)                -0.002774        0.048237 -0.377111
# Seoul_l.rate(지가상승률)           -0.006517       -0.004806 -0.213939
# house_rate(담보대출금리)             0.039514        0.017940  0.149208
# dis_park(국립 공원과의 거리)          -0.072618       -0.105255  0.017893
# dis_highschool(고등학교와의 거리)      0.162671       -0.204004  0.016943
# dis_reconst(재개발 지역과의 거리)       0.214998        0.225095 -0.110684
# dis_univ(대학과의 거리)             -0.702213        0.870612 -0.003616
# dis_hospital(종합 병원과의 거리)      -0.552484        0.167502  0.013588
#
#                            e_grwth(경제성장률)  Seoul_l.rate(지가상승률)  \
# price(가격)                       -0.132575            -0.044081
# con_year(건축년도)                   0.018824             0.003777
# area(면적)                        -0.063985            -0.049426
# floor(층수)                       -0.014200            -0.032827
# Latitude(위도)                    -0.002774            -0.006517
# Longtitude(경도)                   0.048237            -0.004806
# gdp                             -0.377111            -0.213939
# e_grwth(경제성장률)                   1.000000             0.432165
# Seoul_l.rate(지가상승률)              0.432165             1.000000
# house_rate(담보대출금리)              -0.179790            -0.222397
# dis_park(국립 공원과의 거리)            -0.076643            -0.016310
# dis_highschool(고등학교와의 거리)        0.000779             0.012210
# dis_reconst(재개발 지역과의 거리)         0.124114             0.044810
# dis_univ(대학과의 거리)               -0.003406            -0.017573
# dis_hospital(종합 병원과의 거리)        -0.025769             0.035069
#
#                            house_rate(담보대출금리)  ...  dis_hospital(종합 병원과의 거리)  \
# price(가격)                           -0.016064  ...                 -0.027211
# con_year(건축년도)                       0.064364  ...                 -0.567171
# area(면적)                             0.073215  ...                 -0.351692
# floor(층수)                            0.096666  ...                 -0.334654
# Latitude(위도)                         0.039514  ...                 -0.552484
# Longtitude(경도)                       0.017940  ...                  0.167502
# gdp                                  0.149208  ...                  0.013588
# e_grwth(경제성장률)                      -0.179790  ...                 -0.025769
# Seoul_l.rate(지가상승률)                 -0.222397  ...                  0.035069
# house_rate(담보대출금리)                   1.000000  ...                 -0.123207
# dis_park(국립 공원과의 거리)                -0.002624  ...                  0.255695
# dis_highschool(고등학교와의 거리)           -0.010090  ...                  0.070988
# dis_reconst(재개발 지역과의 거리)             0.020718  ...                 -0.220246
# dis_univ(대학과의 거리)                   -0.006254  ...                  0.382893
# dis_hospital(종합 병원과의 거리)            -0.123207  ...                  1.000000
#
#                            dis_museum(국립 박물관과의 거리)  dis_subway(지하철역과의 거리)  \
# price(가격)                                -0.023917               0.032413
# con_year(건축년도)                            0.192700              -0.375835
# area(면적)                                  0.039753              -0.231797
# floor(층수)                                 0.119266              -0.262416
# Latitude(위도)                              0.034464              -0.446530
# Longtitude(경도)                           -0.048959              -0.058008
# gdp                                       0.020654               0.094657
# e_grwth(경제성장률)                            0.008726              -0.069559
# Seoul_l.rate(지가상승률)                       0.037458               0.026834
# house_rate(담보대출금리)                       -0.012885              -0.129616
# dis_park(국립 공원과의 거리)                     -0.093697               0.010135
# dis_highschool(고등학교와의 거리)                 0.028270               0.162948
# dis_reconst(재개발 지역과의 거리)                  0.143299              -0.408034
# dis_univ(대학과의 거리)                        -0.177220               0.215388
# dis_hospital(종합 병원과의 거리)                 -0.135871               0.701023
#
#                            brand_r(유명 아파트 브랜드순)  n_home(세대수)  n_dong(동수)  \
# price(가격)                              0.148241     0.117208    0.077838
# con_year(건축년도)                         0.427227    -0.727402   -0.613206
# area(면적)                               0.146997    -0.350279   -0.382750
# floor(층수)                              0.206511    -0.356595   -0.414505
# Latitude(위도)                           0.129443    -0.429316   -0.454962
# Longtitude(경도)                        -0.271771     0.188727    0.170895
# gdp                                    0.114109     0.060891    0.066403
# e_grwth(경제성장률)                        -0.085838    -0.052561   -0.031194
# Seoul_l.rate(지가상승률)                   -0.018571    -0.002431    0.036049
# house_rate(담보대출금리)                     0.021558    -0.054156   -0.114287
# dis_park(국립 공원과의 거리)                   0.009031     0.319942    0.238979
# dis_highschool(고등학교와의 거리)             -0.002291     0.028045    0.015905
# dis_reconst(재개발 지역과의 거리)               0.048447    -0.383877   -0.348923
# dis_univ(대학과의 거리)                     -0.267132     0.403759    0.396742
# dis_hospital(종합 병원과의 거리)              -0.196103     0.488037    0.592634
#
#                            Yongpae(용적률)  Gunpae(건폐율)  Highest(최고층)  \
# price(가격)                     -0.181609    -0.265625      0.189604
# con_year(건축년도)                 0.513935     0.425801      0.608765
# area(면적)                       0.102846     0.104173      0.346106
# floor(층수)                      0.456448     0.136747      0.621011
# Latitude(위도)                   0.338806     0.406034      0.276134
# Longtitude(경도)                -0.366380    -0.348238     -0.300691
# gdp                           -0.055760    -0.071899      0.026570
# e_grwth(경제성장률)                 0.031346     0.058049     -0.030690
# Seoul_l.rate(지가상승률)           -0.007554     0.016848     -0.045749
# house_rate(담보대출금리)             0.053974    -0.005683      0.123546
# dis_park(국립 공원과의 거리)          -0.072570    -0.078407     -0.073673
# dis_highschool(고등학교와의 거리)      0.015917     0.101806     -0.060888
# dis_reconst(재개발 지역과의 거리)       0.109678     0.138628      0.084104
# dis_univ(대학과의 거리)             -0.453087    -0.448732     -0.386579
# dis_hospital(종합 병원과의 거리)      -0.376078    -0.274252     -0.490496
#
#                            Lowest(최저층)
# price(가격)                     0.099194
# con_year(건축년도)                0.382408
# area(면적)                      0.222335
# floor(층수)                     0.563960
# Latitude(위도)                  0.195107
# Longtitude(경도)               -0.174684
# gdp                          -0.031165
# e_grwth(경제성장률)                0.000478
# Seoul_l.rate(지가상승률)          -0.035941
# house_rate(담보대출금리)            0.120198
# dis_park(국립 공원과의 거리)         -0.019090
# dis_highschool(고등학교와의 거리)    -0.039902
# dis_reconst(재개발 지역과의 거리)      0.092942
# dis_univ(대학과의 거리)            -0.256807
# dis_hospital(종합 병원과의 거리)     -0.396315
#
# [15 rows x 24 columns]

# %%
#Exercise 5

# Correlation in 2006Q1
df2006Q1=df[df['yyyyqrt(거래년도 분기별)']=="2006Q1"] #extracting data in 2006Q1
df2006Q1_apt=df2006Q1.groupby('aptnm(아파트 이름)').mean() #average price
r = df2006Q1_apt.corr()
r_price = r['price(가격)']

plt.figure(figsize=(20,5))
plt.plot(r_price,'o-')
plt.yticks(fontsize = 20); plt.xticks(rotation=45, fontsize = 15, ha = 'right')
plt.title('2006Q1',fontsize=30); 
plt.grid(True)
plt.show()
# Out:
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44148 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 52629 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47732 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 52789 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50948 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47456 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49849 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45812 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48372 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 52636 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44552 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47549 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44284 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44144 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44256 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 46321 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54617 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44368 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50752 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51116 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48156 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50669 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51333 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54633 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48337 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48149 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47932 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54616 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 52384 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50976 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50500 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54028 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 53944 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48652 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47004 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 46300 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49692 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50857 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54224 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50984 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 52572 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51200 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44201 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44148 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 52629 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 47732 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 51201 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 52789 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50948 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 47456 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49849 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 45812 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 48372 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 52636 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44552 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 47549 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44284 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 51032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44144 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44256 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 46321 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54617 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44368 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50752 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 51116 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 48156 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50669 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 51333 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54633 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 48337 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 48149 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 47932 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44288 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54616 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 52384 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50976 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50500 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54028 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 53944 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 48652 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 47004 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 46300 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49692 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50857 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54224 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50984 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 52572 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 51200 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#Correlations in other years.
years = ['2006Q1', '2016Q1', '2017Q1', '2017Q2']

for y in years:
    df_y=df[df['yyyyqrt(거래년도 분기별)']==y] # extract data in 2006Q1
    df_y_apt=df_y.groupby('aptnm(아파트 이름)').mean() #average price
    df_r = df_y_apt.corr()
    df_r_price = df_r['price(가격)']
    if y==years[0]:
        df_r_price_all = df_r_price
    else:
        df_r_price_all = pd.concat([df_r_price_all,df_r_price],axis=1)
df_r_price_all.columns = years


plt.figure(figsize=(20,10))
plt.plot(df_r_price_all,'o-')
plt.yticks(fontsize=20);plt.xticks(rotation=45,fontsize=15,ha='right')
plt.grid(True)
plt.legend(years,fontsize=20)
plt.show()

# %%
#Exercise 6

nMA = 2 #number of Pre(or post) samples to average

plt.figure(figsize=(50,15))
tmp=df[df['dong(동)']=="역삼동"]
tp=tmp.groupby('yyyyqrt(거래년도 분기별)').mean().copy()
ls=[]
for j in range(nMA,len(tp)-nMA):
    ls.append(tp['price(가격)'].iloc[j-nMA:j+nMA].mean())
df_mean5=pd.DataFrame({"Time" : tp.index.values[nMA:len(tp)-nMA], "Mean_Price" : ls })
plt.plot(df_mean5["Time"],df_mean5["Mean_Price"],linewidth=3.0)
plt.yticks(fontsize = 50); plt.xticks(fontsize = 30, rotation = 45, ha = 'right')
plt.grid(True)
df_mean5.set_index("Time",inplace=True)

# %%
plot_acf(df_mean5)
plt.show()
# Out:
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.

# %%
# Difference
plt.figure(figsize=(50,15))
diff_1=df_mean5.diff(periods=1).iloc[1:]
plt.yticks(fontsize = 50); plt.xticks(fontsize = 30, rotation = 45, ha = 'right')
plt.plot(diff_1,  linewidth=3.0)
plt.axhline(y=0, color='r', linewidth=3.0)
plt.grid(True)

# %%
plot_acf(diff_1)
plt.show()

# %%
from statsmodels.tsa.arima_model import ARIMA
train = diff_1.iloc[:38] # 38 out of 42 samples
test = diff_1.iloc[38:] # 4 out of 42 samples
model = ARIMA(train,order=(1,0,0)) #order=(p,d,q), here we only use  p = 1

# Nc: No constant used / convergence information is not printed
model_fit = model.fit(trend='Nc',disp=0);
print(model_fit.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:             Mean_Price   No. Observations:                   38
# Model:                     ARMA(1, 0)   Log Likelihood                -355.356
# Method:                       css-mle   S.D. of innovations           2775.350
# Date:                Wed, 06 Apr 2022   AIC                            714.711
# Time:                        02:31:44   BIC                            717.986
# Sample:                    10-01-2006   HQIC                           715.877
#                          - 01-01-2016
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ar.L1.Mean_Price     0.5117      0.152      3.366      0.001       0.214       0.810
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.9544           +0.0000j            1.9544            0.0000
# -----------------------------------------------------------------------------
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# /Users/kim-yneun/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   warnings.warn('No frequency information was'

# %%
#plot the result (predicted value and true value) for traing samples
predict = "______________"

# %%
fc,se,conf=model_fit.forecast(steps=4,alpha=0.05)
fc_series=pd.Series(fc,index=test.index)


plt.figure(figsize=(40,10), dpi=100)
plt.plot(diff_1, linewidth = 3.0, label='training')
plt.plot(test,  linewidth = 3.0, label='actual')
plt.plot(fc_series, linewidth = 3.0, label='forecast')
plt.legend(fontsize=50)
plt.yticks(fontsize = 50); plt.xticks(fontsize = 30, rotation = 45, ha = 'right')
plt.grid(True)

#**** code for highlight the target area ***
#lower_series = pd.Series(conf[:, 0], index=test.index)
#upper_series = pd.Series(conf[:, 1], index=test.index)
#plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.15)
