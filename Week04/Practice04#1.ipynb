# %%
import pandas as pd
df=pd.read_csv('titanic_train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby(['Sex','Pclass','Survived']).mean()
# Out:
#                         PassengerId        Age     SibSp     Parch        Fare
# Sex    Pclass Survived
# female 1      0          325.000000  25.666667  0.666667  1.333333  110.604167
#               1          473.967033  34.939024  0.549451  0.428571  105.978159
#        2      0          423.500000  36.000000  0.500000  0.166667   18.250000
#               1          444.785714  28.080882  0.485714  0.642857   22.288989
#        3      0          440.375000  23.818182  1.291667  1.097222   19.773093
#               1          359.083333  19.329787  0.500000  0.500000   12.464526
# male   1      0          413.623377  44.581967  0.272727  0.259740   62.894910
#               1          527.777778  36.248000  0.377778  0.311111   74.637320
#        2      0          454.010989  33.369048  0.307692  0.142857   19.488965
#               1          415.588235  16.022000  0.529412  0.647059   21.095100
#        3      0          456.750000  27.255814  0.523333  0.213333   12.204469
# ...

# %%
df.groupby(['PassengerId','Sex', 'Pclass','Survived']).mean()
# Out:
#                                      Age  SibSp  Parch     Fare
# PassengerId Sex    Pclass Survived
# 1           male   3      0         22.0      1      0   7.2500
# 2           female 1      1         38.0      1      0  71.2833
# 3           female 3      1         26.0      0      0   7.9250
# 4           female 1      1         35.0      1      0  53.1000
# 5           male   3      0         35.0      0      0   8.0500
# ...                                  ...    ...    ...      ...
# 887         male   2      0         27.0      0      0  13.0000
# 888         female 1      1         19.0      0      0  30.0000
# 889         female 3      0          NaN      1      2  23.4500
# 890         male   1      1         26.0      0      0  30.0000
# 891         male   3      0         32.0      0      0   7.7500
#
# [891 rows x 4 columns]

# %%
df1=df.iloc[:,0:5]

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# ...

# %%
df1.drop(columns=['PassengerId','Name'],inplace=True)

# %%
df1
# Out:
#      Survived  Pclass     Sex
# 0           0       3    male
# 1           1       1  female
# 2           1       3  female
# 3           1       1  female
# 4           0       3    male
# ..        ...     ...     ...
# 886         0       2    male
# 887         1       1  female
# 888         0       3  female
# 889         1       1    male
# 890         0       3    male
#
# [891 rows x 3 columns]

# %%
option=(df1.Survived == 1)
df2=df1[option]

# %%
df2
# Out:
#      Survived  Pclass     Sex
# 1           1       1  female
# 2           1       3  female
# 3           1       1  female
# 8           1       3  female
# 9           1       2  female
# ..        ...     ...     ...
# 875         1       3  female
# 879         1       1  female
# 880         1       2  female
# 887         1       1  female
# 889         1       1    male
#
# [342 rows x 3 columns]

# %%
female=(df2.Sex == "female")
df_f=df2[female]

# %%
df_f.shape
# Out:
# (233, 3)

# %%
p1=(df2.Pclass==1)
df_f[p1]
# Out:
# <ipython-input-37-f65e39fe4a64>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_f[p1]
#      Survived  Pclass     Sex
# 1           1       1  female
# 3           1       1  female
# 11          1       1  female
# 31          1       1  female
# 52          1       1  female
# ..        ...     ...     ...
# 856         1       1  female
# 862         1       1  female
# 871         1       1  female
# 879         1       1  female
# 887         1       1  female
#
# [91 rows x 3 columns]

# %%
r,c = df_f[p1].shape
# Out:
# <ipython-input-40-168056990b1f>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   r,c = df_f[p1].shape

# %%
r
# Out:
# 91

# %%
df2
for i in range (1,4):
    female=(df2.Sex == "female")
    df_f=df2[female]
    p1=(df2.Pclass==i)
    df_f[p1]
    r,c = df_f[p1].shape
    print(r)
# Out:
# 91
# 70
# 72
# <ipython-input-45-1b49e45c172b>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_f[p1]
# <ipython-input-45-1b49e45c172b>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   r,c = df_f[p1].shape
# <ipython-input-45-1b49e45c172b>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_f[p1]
# <ipython-input-45-1b49e45c172b>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   r,c = df_f[p1].shape
# <ipython-input-45-1b49e45c172b>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_f[p1]
# <ipython-input-45-1b49e45c172b>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   r,c = df_f[p1].shape

# %%
df2
for i in range (1,4):
    male=(df2.Sex == "male")
    df_f=df2[male]
    p1=(df2.Pclass==i)
    df_f[p1]
    r,c = df_f[p1].shape
    print(r)
# Out:
# 45
# 17
# 47
# <ipython-input-46-198e727a676e>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_f[p1]
# <ipython-input-46-198e727a676e>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   r,c = df_f[p1].shape
# <ipython-input-46-198e727a676e>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_f[p1]
# <ipython-input-46-198e727a676e>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   r,c = df_f[p1].shape
# <ipython-input-46-198e727a676e>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_f[p1]
# <ipython-input-46-198e727a676e>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   r,c = df_f[p1].shape

# %%
df2
for i in range (1,4):
    male=(df2.Sex == "male")
    df_f=df2[male]
    p1=(df2.Pclass==i)
    df_f[p1]
    r,c = df_f[p1].shape
    print("group: ('male',",i,end='')
    print(") => ",r)
# Out:
# group: ('male', 1) =>  45
# group: ('male', 2) =>  17
# group: ('male', 3) =>  47
# <ipython-input-52-1afc5cd8fb65>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_f[p1]
# <ipython-input-52-1afc5cd8fb65>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   r,c = df_f[p1].shape
# <ipython-input-52-1afc5cd8fb65>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_f[p1]
# <ipython-input-52-1afc5cd8fb65>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   r,c = df_f[p1].shape
# <ipython-input-52-1afc5cd8fb65>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_f[p1]
# <ipython-input-52-1afc5cd8fb65>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   r,c = df_f[p1].shape

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2
for i in range (1,4):
    female=(df2.Sex == "female")
    df_f=df2[female]
    p1=(df2.Pclass==i)
    df_f[p1]
    r,c = df_f[p1].shape
    print("group: ('female',",i,end='')
    print(") => ",r)

for i in range (1,4):
    male=(df2.Sex == "male")
    df_f=df2[male]
    p1=(df2.Pclass==i)
    df_f[p1]
    r,c = df_f[p1].shape
    print("group: ('male',",i,end='')
    print(") => ",r)
# Out:
# group: ('female', 1) =>  91
# group: ('female', 2) =>  70
# group: ('female', 3) =>  72
# group: ('male', 1) =>  45
# group: ('male', 2) =>  17
# group: ('male', 3) =>  47
# <ipython-input-55-f4550284ea5d>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_f[p1]
# <ipython-input-55-f4550284ea5d>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   r,c = df_f[p1].shape
# <ipython-input-55-f4550284ea5d>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_f[p1]
# <ipython-input-55-f4550284ea5d>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   r,c = df_f[p1].shape
# <ipython-input-55-f4550284ea5d>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_f[p1]
# <ipython-input-55-f4550284ea5d>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   r,c = df_f[p1].shape
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1
# Out:
#      Survived  Pclass     Sex
# 0           0       3    male
# 1           1       1  female
# 2           1       3  female
# 3           1       1  female
# 4           0       3    male
# ..        ...     ...     ...
# 886         0       2    male
# 887         1       1  female
# 888         0       3  female
# 889         1       1    male
# 890         0       3    male
#
# [891 rows x 3 columns]

# %%
no=(df1.Survived==0)
df_d=df1[no]

# %%
df_d
# Out:
#      Survived  Pclass     Sex
# 0           0       3    male
# 4           0       3    male
# 5           0       3    male
# 6           0       1    male
# 7           0       3    male
# ..        ...     ...     ...
# 884         0       3    male
# 885         0       3  female
# 886         0       2    male
# 888         0       3  female
# 890         0       3    male
#
# [549 rows x 3 columns]

# %%
for i in range (1,4):
    female=(df_d.Sex == "female")
    df_2=df_d[female]
    p1=(df_2.Pclass==i)
    df_2[p1]
    r,c = df_2[p1].shape
    print("group: ('female',",i,end='')
    print(") => ",r)

for i in range (1,4):
    male=(df_d.Sex == "male")
    df_2=df_d[male]
    p1=(df_2.Pclass==i)
    df_2[p1]
    r,c = df_2[p1].shape
    print("group: ('male',",i,end='')
    print(") => ",r)
# Out:
# group: ('female', 1) =>  3
# group: ('female', 2) =>  6
# group: ('female', 3) =>  72
# group: ('male', 1) =>  77
# group: ('male', 2) =>  91
# group: ('male', 3) =>  300
